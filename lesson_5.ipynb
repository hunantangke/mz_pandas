# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
dates = pd.date_range('20170506',periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2017-05-06', '2017-05-07', '2017-05-08', '2017-05-09',
#                '2017-05-10', '2017-05-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
date = pd.DataFrame(np.random.randn(6, 4),index=dates,columns=list('ABCD'))

# %%
date
# Out:
#                    A         B         C         D
# 2017-05-06  0.459726  0.688286  2.149639 -2.507344
# 2017-05-07  1.466782  0.252530  0.658815 -2.096200
# 2017-05-08  0.455601  0.169823 -1.453497  0.057834
# 2017-05-09  0.248949  0.014150 -1.323309  1.216525
# 2017-05-10  0.161187 -0.337262 -1.350082 -0.762095
# 2017-05-11 -0.490398  0.494722  0.124335 -1.627793

# %%
df1 = date.reindex(index=dates[0:4],columns=list(date.columns)+ ['E'])

# %%
df1
# Out:
#                    A         B         C         D   E
# 2017-05-06  0.459726  0.688286  2.149639 -2.507344 NaN
# 2017-05-07  1.466782  0.252530  0.658815 -2.096200 NaN
# 2017-05-08  0.455601  0.169823 -1.453497  0.057834 NaN
# 2017-05-09  0.248949  0.014150 -1.323309  1.216525 NaN

# %%
df1.loc[dates[1:3],['E']] = 2

# %%
df1
# Out:
#                    A         B         C         D    E
# 2017-05-06  0.459726  0.688286  2.149639 -2.507344  NaN
# 2017-05-07  1.466782  0.252530  0.658815 -2.096200  2.0
# 2017-05-08  0.455601  0.169823 -1.453497  0.057834  2.0
# 2017-05-09  0.248949  0.014150 -1.323309  1.216525  NaN

# %%
df1.dropna()
# Out:
#                    A         B         C         D    E
# 2017-05-07  1.466782  0.252530  0.658815 -2.096200  2.0
# 2017-05-08  0.455601  0.169823 -1.453497  0.057834  2.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C         D    E
# 2017-05-06  0.459726  0.688286  2.149639 -2.507344  5.0
# 2017-05-07  1.466782  0.252530  0.658815 -2.096200  2.0
# 2017-05-08  0.455601  0.169823 -1.453497  0.057834  2.0
# 2017-05-09  0.248949  0.014150 -1.323309  1.216525  5.0

# %%
pd.isnull(df1).any()
# Out:
# A    False
# B    False
# C    False
# D    False
# E     True
# dtype: bool

# %%
df1.describe()
# Out:
#               A         B         C         D    E
# count  4.000000  4.000000  4.000000  4.000000  2.0
# mean   0.657765  0.281197  0.007912 -0.832296  2.0
# std    0.548249  0.288826  1.724194  1.769486  0.0
# min    0.248949  0.014150 -1.453497 -2.507344  2.0
# 25%    0.403938  0.130904 -1.355856 -2.198986  2.0
# 50%    0.457663  0.211176 -0.332247 -1.019183  2.0
# 75%    0.711490  0.361469  1.031521  0.347507  2.0
# max    1.466782  0.688286  2.149639  1.216525  2.0

# %%
df1.mean()
# Out:
# A    0.657765
# B    0.281197
# C    0.007912
# D   -0.832296
# E    2.000000
# dtype: float64

# %%
df1.mean(1)
# Out:
# 2017-05-06    0.197577
# 2017-05-07    0.456385
# 2017-05-08    0.245952
# 2017-05-09    0.039079
# Freq: D, dtype: float64

# %%
df1
# Out:
#                    A         B         C         D    E
# 2017-05-06  0.459726  0.688286  2.149639 -2.507344  NaN
# 2017-05-07  1.466782  0.252530  0.658815 -2.096200  2.0
# 2017-05-08  0.455601  0.169823 -1.453497  0.057834  2.0
# 2017-05-09  0.248949  0.014150 -1.323309  1.216525  NaN

# %%
df1.cumsum()
# Out:
#                    A         B         C         D    E
# 2017-05-06  0.459726  0.688286  2.149639 -2.507344  NaN
# 2017-05-07  1.926508  0.940815  2.808454 -4.603544  2.0
# 2017-05-08  2.382109  1.110638  1.354956 -4.545710  4.0
# 2017-05-09  2.631058  1.124787  0.031648 -3.329185  NaN

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df1
# Out:
#                    A         B         C         D    E
# 2017-05-06  0.459726  0.688286  2.149639 -2.507344  NaN
# 2017-05-07  1.466782  0.252530  0.658815 -2.096200  2.0
# 2017-05-08  0.455601  0.169823 -1.453497  0.057834  2.0
# 2017-05-09  0.248949  0.014150 -1.323309  1.216525  NaN

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
dates
# Out:
# DatetimeIndex(['2017-05-06', '2017-05-07', '2017-05-08', '2017-05-09',
#                '2017-05-10', '2017-05-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2017-05-06 -0.442836 -0.952509 -1.137950 -0.941660
# 2017-05-07 -0.318148 -0.244185 -0.021928 -3.762592
# 2017-05-08 -0.248620  0.861361 -0.914089 -0.593646
# 2017-05-09  0.499301  0.638169  0.270685 -0.886554
# 2017-05-10  0.504398  2.025094  0.899836 -1.897487
# 2017-05-11 -0.179072  1.311053 -0.689404 -0.766361

# %%
df.cumsum()
# Out:
#                    A         B         C         D
# 2017-05-06 -0.442836 -0.952509 -1.137950 -0.941660
# 2017-05-07 -0.760984 -1.196694 -1.159879 -4.704251
# 2017-05-08 -1.009605 -0.335333 -2.073967 -5.297898
# 2017-05-09 -0.510303  0.302836 -1.803282 -6.184452
# 2017-05-10 -0.005906  2.327929 -0.903446 -8.081939
# 2017-05-11 -0.184977  3.638983 -1.592850 -8.848300

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2017-05-06 -0.442836 -0.952509 -1.137950 -0.941660
# 2017-05-07 -0.760984 -1.196694 -1.159879 -4.704251
# 2017-05-08 -1.009605 -0.335333 -2.073967 -5.297898
# 2017-05-09 -0.510303  0.302836 -1.803282 -6.184452
# 2017-05-10 -0.005906  2.327929 -0.903446 -8.081939
# 2017-05-11 -0.184977  3.638983 -1.592850 -8.848300

# %%
df.max()
# Out:
# A    0.504398
# B    2.025094
# C    0.899836
# D   -0.593646
# dtype: float64

# %%
df.apply(lambda x:x.max()-x.min())
# Out:
# A    0.947234
# B    2.977603
# C    2.037786
# D    3.168945
# dtype: float64

# %%
s = pd.Series(np.random.randint(1,20,size=20))

# %%
s
# Out:
# 0      6
# 1      3
# 2     19
# 3     16
# 4      4
# 5     10
# 6     14
# 7      5
# 8      7
# 9     13
# 10     9
# 11     1
# 12     7
# 13    14
# 14    17
# 15    18
# 16     7
# 17     9
# 18    13
# 19     8
# dtype: int32

# %%
s.value_counts()
# Out:
# 7     3
# 14    2
# 13    2
# 9     2
# 19    1
# 18    1
# 17    1
# 16    1
# 10    1
# 8     1
# 6     1
# 5     1
# 4     1
# 3     1
# 1     1
# dtype: int64

# %%
s.mode()
# Out:
# 0    7
# dtype: int32

# %%
df = pd.DataFrame(np.random.randn(10,4),columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0  0.293191 -0.924557 -0.755125  0.852449
# 1  0.414124  1.901795  1.042540  0.762331
# 2 -2.439323  0.713879  0.213981 -0.404695
# 3  0.533851 -0.106314  0.130582  0.725204
# 4  1.076881  0.252428  0.027422 -1.767512
# 5 -1.487711 -0.332014 -0.718491  0.116719
# 6 -0.651620 -0.988439 -1.662341 -1.067310
# 7  1.413039  1.547054  0.072787  1.828186
# 8 -0.679472 -0.312470 -0.270118  0.584717
# 9  2.107803 -1.186273 -1.701169  0.356925

# %%
df.iloc[:3]
# Out:
#           A         B         C         D
# 0  0.293191 -0.924557 -0.755125  0.852449
# 1  0.414124  1.901795  1.042540  0.762331
# 2 -2.439323  0.713879  0.213981 -0.404695

# %%
df.iloc[3:7]
# Out:
#           A         B         C         D
# 3  0.533851 -0.106314  0.130582  0.725204
# 4  1.076881  0.252428  0.027422 -1.767512
# 5 -1.487711 -0.332014 -0.718491  0.116719
# 6 -0.651620 -0.988439 -1.662341 -1.067310

# %%
df.iloc[7:]
# Out:
#           A         B         C         D
# 7  1.413039  1.547054  0.072787  1.828186
# 8 -0.679472 -0.312470 -0.270118  0.584717
# 9  2.107803 -1.186273 -1.701169  0.356925

# %%
df.iloc[7:,2:]
# Out:
#           C         D
# 7  0.072787  1.828186
# 8 -0.270118  0.584717
# 9 -1.701169  0.356925

# %%
df1 = pd.concat([df.iloc[:3],df.iloc[3:7],df.iloc[7:]])
df1
# Out:
#           A         B         C         D
# 0  0.293191 -0.924557 -0.755125  0.852449
# 1  0.414124  1.901795  1.042540  0.762331
# 2 -2.439323  0.713879  0.213981 -0.404695
# 3  0.533851 -0.106314  0.130582  0.725204
# 4  1.076881  0.252428  0.027422 -1.767512
# 5 -1.487711 -0.332014 -0.718491  0.116719
# 6 -0.651620 -0.988439 -1.662341 -1.067310
# 7  1.413039  1.547054  0.072787  1.828186
# 8 -0.679472 -0.312470 -0.270118  0.584717
# 9  2.107803 -1.186273 -1.701169  0.356925

# %%
df==df1
# Out:
#       A     B     C     D
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
# 4  True  True  True  True
# 5  True  True  True  True
# 6  True  True  True  True
# 7  True  True  True  True
# 8  True  True  True  True
# 9  True  True  True  True

# %%
(df==df1).all()
# Out:
# A    True
# B    True
# C    True
# D    True
# dtype: bool

# %%
(df==df1).all().all()
# Out:
# True

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                          'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                          'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.597096 -0.416921
# 1  bar    one -0.293865 -0.977515
# 2  foo    two -0.383522 -0.159947
# 3  bar  three  0.660924  1.415350
# 4  foo    two -0.786944  0.727960
# 5  bar    two  0.198817  1.126477
# 6  foo    one  0.564521  0.186336
# 7  foo  three -0.776913 -0.006235

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.565875  1.564312
# foo -0.785762  0.331194

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.293865 -0.977515
#     three  0.660924  1.415350
#     two    0.198817  1.126477
# foo one    1.161617 -0.230585
#     three -0.776913 -0.006235
#     two   -1.170467  0.568013

# %%
df.groupby(['B','A']).sum()
# Out:
#                   C         D
# B     A
# one   bar -0.293865 -0.977515
#       foo  1.161617 -0.230585
# three bar  0.660924  1.415350
#       foo -0.776913 -0.006235
# two   bar  0.198817  1.126477
#       foo -1.170467  0.568013

# %%
 df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B' : ['A', 'B', 'C'] * 4,
   .....:                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D' : np.random.randn(12),
   .....:                    'E' : np.random.randn(12)})
    df
# Out:
#   File "<ipython-input-78-814753570794>", line 6
#     df
#     ^
# IndentationError: unexpected indent

# %%
 df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B' : ['A', 'B', 'C'] * 4,
   .....:                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D' : np.random.randn(12),
   .....:                    'E' : np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -2.337234  0.190309
# 1     one  B  foo -0.659827  0.883686
# 2     two  C  foo  0.268068 -1.562922
# 3   three  A  bar  2.624591  1.152850
# 4     one  B  bar -2.284613  0.637058
# 5     one  C  bar  0.575570  0.215477
# 6     two  A  foo -0.691748  0.064960
# 7   three  B  foo  0.829072  0.675036
# 8     one  C  foo -0.509569  1.942949
# 9     one  A  bar -0.359635 -0.272619
# 10    two  B  bar -1.260398 -0.087564
# 11  three  C  bar  0.393308  2.318923

# %%
df.pivot_table(values=['D'],index=['A','B'],columns=['C'])
# Out:
#                 D
# C             bar       foo
# A     B
# one   A -0.359635 -2.337234
#       B -2.284613 -0.659827
#       C  0.575570 -0.509569
# three A  2.624591       NaN
#       B       NaN  0.829072
#       C  0.393308       NaN
# two   A       NaN -0.691748
#       B -1.260398       NaN
#       C       NaN  0.268068

# %%
rng = pd.date_range('20170506',periods=600,freq='s')
rng
# Out:
# DatetimeIndex(['2017-05-06 00:00:00', '2017-05-06 00:00:01',
#                '2017-05-06 00:00:02', '2017-05-06 00:00:03',
#                '2017-05-06 00:00:04', '2017-05-06 00:00:05',
#                '2017-05-06 00:00:06', '2017-05-06 00:00:07',
#                '2017-05-06 00:00:08', '2017-05-06 00:00:09',
#                ...
#                '2017-05-06 00:09:50', '2017-05-06 00:09:51',
#                '2017-05-06 00:09:52', '2017-05-06 00:09:53',
#                '2017-05-06 00:09:54', '2017-05-06 00:09:55',
#                '2017-05-06 00:09:56', '2017-05-06 00:09:57',
#                '2017-05-06 00:09:58', '2017-05-06 00:09:59'],
#               dtype='datetime64[ns]', length=600, freq='S')

# %%
s = pd.Series(np.random.randint(0,50,len(rng)),index=rng)

# %%
s
# Out:
# 2017-05-06 00:00:00    48
# 2017-05-06 00:00:01     1
# 2017-05-06 00:00:02    20
# 2017-05-06 00:00:03    42
# 2017-05-06 00:00:04    16
# 2017-05-06 00:00:05     8
# 2017-05-06 00:00:06     7
# 2017-05-06 00:00:07    15
# 2017-05-06 00:00:08    41
# 2017-05-06 00:00:09     9
# 2017-05-06 00:00:10    14
# 2017-05-06 00:00:11    35
# 2017-05-06 00:00:12    25
# 2017-05-06 00:00:13    17
# 2017-05-06 00:00:14     8
# 2017-05-06 00:00:15    31
# 2017-05-06 00:00:16    40
# 2017-05-06 00:00:17     7
# 2017-05-06 00:00:18     1
# 2017-05-06 00:00:19    16
# 2017-05-06 00:00:20     2
# 2017-05-06 00:00:21    40
# 2017-05-06 00:00:22     4
# 2017-05-06 00:00:23    33
# 2017-05-06 00:00:24    28
# 2017-05-06 00:00:25    38
# 2017-05-06 00:00:26     8
# 2017-05-06 00:00:27    27
# 2017-05-06 00:00:28     2
# 2017-05-06 00:00:29    37
#                        ..
# 2017-05-06 00:09:30     0
# 2017-05-06 00:09:31    11
# 2017-05-06 00:09:32     9
# 2017-05-06 00:09:33     6
# ...

# %%
s.resample('2Min').sum()
# Out:
# 2017-05-06 00:00:00    2780
# 2017-05-06 00:02:00    2891
# 2017-05-06 00:04:00    3078
# 2017-05-06 00:06:00    2935
# 2017-05-06 00:08:00    2531
# Freq: 2T, dtype: int32

# %%
s.resample('2Min').mean()
# Out:
# 2017-05-06 00:00:00    23.166667
# 2017-05-06 00:02:00    24.091667
# 2017-05-06 00:04:00    25.650000
# 2017-05-06 00:06:00    24.458333
# 2017-05-06 00:08:00    21.091667
# Freq: 2T, dtype: float64

# %%
In [122]: df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df['grade'] = df.raw_grade.astype('category')

# %%
df
# Out:
#    id raw_grade grade
# 0   1         a     a
# 1   2         b     b
# 2   3         b     b
# 3   4         a     a
# 4   5         a     a
# 5   6         e     e

# %%
df = pd.DataFrame(np.random.randn(1000),index=pd.date_range('20170101',periods=1000))

# %%
df
# Out:
#                    0
# 2017-01-01  1.008793
# 2017-01-02  0.211685
# 2017-01-03 -0.054778
# 2017-01-04 -0.655619
# 2017-01-05  1.014608
# 2017-01-06 -0.315480
# 2017-01-07  0.593917
# 2017-01-08  0.656567
# 2017-01-09 -0.329162
# 2017-01-10 -0.028357
# 2017-01-11  0.285415
# 2017-01-12 -1.012061
# 2017-01-13 -0.686599
# 2017-01-14  0.932057
# 2017-01-15  2.015646
# 2017-01-16  0.350641
# 2017-01-17 -1.527075
# 2017-01-18 -1.380368
# 2017-01-19  1.075122
# 2017-01-20  0.217516
# 2017-01-21  0.337869
# 2017-01-22  1.506320
# 2017-01-23  0.735576
# 2017-01-24  0.784733
# 2017-01-25  1.277575
# 2017-01-26  1.671345
# 2017-01-27  0.608316
# 2017-01-28  1.213569
# 2017-01-29  0.137371
# 2017-01-30 -0.690642
# ...              ...
# 2019-08-29 -0.627599
# 2019-08-30  0.742758
# 2019-08-31 -1.403601
# 2019-09-01  1.319286
# 2019-09-02  0.320142
# 2019-09-03  1.808756
# 2019-09-04 -0.856625
# 2019-09-05 -0.614549
# 2019-09-06 -0.187169
# 2019-09-07  1.608097
# 2019-09-08 -0.043870
# ...

# %%
df.cumsum()
# Out:
#                     0
# 2017-01-01   1.008793
# 2017-01-02   1.220478
# 2017-01-03   1.165699
# 2017-01-04   0.510080
# 2017-01-05   1.524688
# 2017-01-06   1.209209
# 2017-01-07   1.803125
# 2017-01-08   2.459692
# 2017-01-09   2.130530
# 2017-01-10   2.102174
# 2017-01-11   2.387589
# 2017-01-12   1.375528
# 2017-01-13   0.688929
# 2017-01-14   1.620987
# 2017-01-15   3.636633
# 2017-01-16   3.987274
# 2017-01-17   2.460199
# 2017-01-18   1.079832
# 2017-01-19   2.154953
# 2017-01-20   2.372469
# 2017-01-21   2.710338
# 2017-01-22   4.216658
# 2017-01-23   4.952234
# 2017-01-24   5.736967
# 2017-01-25   7.014542
# 2017-01-26   8.685887
# 2017-01-27   9.294203
# 2017-01-28  10.507773
# 2017-01-29  10.645144
# 2017-01-30   9.954502
# ...               ...
# 2019-08-29  72.750644
# 2019-08-30  73.493402
# 2019-08-31  72.089801
# 2019-09-01  73.409087
# 2019-09-02  73.729229
# 2019-09-03  75.537985
# 2019-09-04  74.681360
# 2019-09-05  74.066811
# 2019-09-06  73.879642
# ...

# %%
s.plot()

# %%
df.plot()

# %%
s = pd.Series(np.random.randn(1000),index=pd.date_range('20170101',periods=1000))

# %%
s
# Out:
# 2017-01-01    1.607283
# 2017-01-02   -1.132134
# 2017-01-03    1.076607
# 2017-01-04    0.009525
# 2017-01-05    0.140903
# 2017-01-06    0.734945
# 2017-01-07   -0.027149
# 2017-01-08    0.564625
# 2017-01-09    0.666479
# 2017-01-10    0.509471
# 2017-01-11    0.017611
# 2017-01-12   -1.643159
# 2017-01-13   -0.599510
# 2017-01-14   -0.593895
# 2017-01-15    0.203452
# 2017-01-16   -0.205975
# 2017-01-17   -0.108692
# 2017-01-18   -1.782188
# 2017-01-19    1.281267
# 2017-01-20    1.479735
# 2017-01-21    0.099378
# 2017-01-22    1.420937
# 2017-01-23   -0.197822
# 2017-01-24    0.713680
# 2017-01-25   -0.716430
# 2017-01-26   -2.008706
# 2017-01-27   -0.918783
# 2017-01-28   -1.914449
# 2017-01-29   -0.008785
# 2017-01-30   -0.036669
#                 ...
# 2019-08-29    0.637879
# 2019-08-30    0.312473
# 2019-08-31   -0.442245
# 2019-09-01    1.749156
# 2019-09-02   -0.404907
# 2019-09-03    1.188836
# 2019-09-04    0.471687
# 2019-09-05    2.639546
# 2019-09-06    1.944170
# ...

# %%
s.cumsum()
# Out:
# 2017-01-01     1.607283
# 2017-01-02     0.475149
# 2017-01-03     1.551756
# 2017-01-04     1.561282
# 2017-01-05     1.702185
# 2017-01-06     2.437129
# 2017-01-07     2.409980
# 2017-01-08     2.974605
# 2017-01-09     3.641085
# 2017-01-10     4.150556
# 2017-01-11     4.168167
# 2017-01-12     2.525008
# 2017-01-13     1.925498
# 2017-01-14     1.331603
# 2017-01-15     1.535055
# 2017-01-16     1.329080
# 2017-01-17     1.220388
# 2017-01-18    -0.561800
# 2017-01-19     0.719466
# 2017-01-20     2.199202
# 2017-01-21     2.298580
# 2017-01-22     3.719517
# 2017-01-23     3.521695
# 2017-01-24     4.235375
# 2017-01-25     3.518945
# 2017-01-26     1.510239
# 2017-01-27     0.591455
# 2017-01-28    -1.322994
# 2017-01-29    -1.331779
# 2017-01-30    -1.368448
#                 ...
# 2019-08-29    22.526620
# 2019-08-30    22.839093
# 2019-08-31    22.396848
# 2019-09-01    24.146004
# 2019-09-02    23.741097
# 2019-09-03    24.929933
# 2019-09-04    25.401620
# ...

# %%
s.plot()

# %%
s = s.cumsum()

# %%
s.plot()

# %%
df = pd.DataFrame(np.random.randn(1000),index=pd.date_range('20110101',periods=1000))

# %%
df
# Out:
#                    0
# 2011-01-01  0.170981
# 2011-01-02 -0.509602
# 2011-01-03  1.667112
# 2011-01-04 -1.073667
# 2011-01-05 -0.754003
# 2011-01-06 -0.558758
# 2011-01-07  0.835020
# 2011-01-08  0.601754
# 2011-01-09  0.873456
# 2011-01-10  2.591932
# 2011-01-11  0.943231
# 2011-01-12  0.323763
# 2011-01-13 -0.586088
# 2011-01-14 -1.783268
# 2011-01-15  0.619040
# 2011-01-16  1.252374
# 2011-01-17 -1.988933
# 2011-01-18 -1.828438
# 2011-01-19  0.296768
# 2011-01-20  0.456763
# 2011-01-21  1.679312
# 2011-01-22  0.719650
# 2011-01-23 -1.115309
# 2011-01-24 -0.720242
# 2011-01-25  0.257312
# 2011-01-26 -0.139356
# 2011-01-27 -0.953226
# 2011-01-28 -0.257123
# 2011-01-29 -1.036979
# 2011-01-30 -1.648637
# ...              ...
# 2013-08-28  1.192769
# 2013-08-29  2.483241
# 2013-08-30  1.108551
# 2013-08-31 -0.575988
# 2013-09-01 -0.487723
# 2013-09-02 -1.270056
# 2013-09-03  0.832229
# 2013-09-04 -0.120893
# 2013-09-05  0.769821
# 2013-09-06 -0.542927
# 2013-09-07 -1.042332
# ...

# %%
df = df.cumsum()

# %%
df.plot()

# %%
df = pd.DataFrame(np.random.randn(100,4),columns=list('ABCD'))

# %%
df
# Out:
#            A         B         C         D
# 0  -2.031309 -2.037559  0.767547  1.807622
# 1  -0.484605 -0.226629  0.834595  0.382444
# 2   1.002624 -0.352282  0.811769 -0.771234
# 3   1.279125 -0.219258  0.463970  1.710032
# 4   0.827671 -0.161500 -0.603888 -0.991564
# 5  -1.174889  0.790357  0.277971 -0.562625
# 6  -0.156444  1.317961  0.460263  0.143097
# 7   0.354895 -0.314679 -0.949182 -1.118730
# 8  -1.085285 -0.135187 -0.045841 -0.068558
# 9  -0.904385  0.281998  2.817118  0.964935
# 10  0.100230  0.498819 -1.332437  1.528207
# 11 -1.257667  0.997186  1.181825 -0.386610
# 12  1.478010  0.914310 -2.055094 -0.242988
# 13  0.376282  0.084568  0.906954 -0.330540
# 14  0.189882 -0.254156 -0.166407  1.174214
# 15  0.144269 -1.982706  1.309398 -0.298349
# 16 -1.553618  0.362949 -0.489144 -0.742669
# 17  0.009313 -0.788533  0.445267 -1.704204
# 18 -0.957463 -0.011264 -0.247352  1.399010
# 19  1.645806  0.227912 -1.246545  0.173152
# 20 -0.843259 -0.150075  0.855650 -0.676852
# ...

# %%
df.to_csv('ss.csv')

# %%
ls
# Out:
#  驱动器 C 中的卷是 Acer
#  卷的序列号是 2228-EE3A
#
#  C:\Users\tang\Desktop\python\mz_pandas 的目录
#
# 2017/05/06  18:44    <DIR>          .
# 2017/05/06  18:44    <DIR>          ..
# 2017/05/06  12:24    <DIR>          .ipynb_checkpoints
# 2017/05/06  18:43           296,387 lesson_5.ipynb
# 2017/04/03  21:23             2,883 python_demo.ipynb
# 2017/05/06  18:44             6,470 ss.csv
# 2017/05/03  17:20             1,699 Untitled.ipynb
#                4 个文件        307,439 字节
#                3 个目录 201,230,831,616 可用字节

# %%
# %ls
# Out:
#  驱动器 C 中的卷是 Acer
#  卷的序列号是 2228-EE3A
#
#  C:\Users\tang\Desktop\python\mz_pandas 的目录
#
# 2017/05/06  18:44    <DIR>          .
# 2017/05/06  18:44    <DIR>          ..
# 2017/05/06  12:24    <DIR>          .ipynb_checkpoints
# 2017/05/06  18:43           296,387 lesson_5.ipynb
# 2017/04/03  21:23             2,883 python_demo.ipynb
# 2017/05/06  18:44             6,470 ss.csv
# 2017/05/03  17:20             1,699 Untitled.ipynb
#                4 个文件        307,439 字节
#                3 个目录 201,230,827,520 可用字节

# %%
cat ss.csv
# Out:
#   File "<ipython-input-124-2c39203962c0>", line 1
#     cat ss.csv
#          ^
# SyntaxError: invalid syntax

# %%
more ss.csv

# %%
vi ss.csv
# Out:
#   File "<ipython-input-126-695ab9e1ca2f>", line 1
#     vi ss.csv
#         ^
# SyntaxError: invalid syntax

# %%
pd.read_csv('ss.csv',index_col=0)
# Out:
#            A         B         C         D
# 0  -2.031309 -2.037559  0.767547  1.807622
# 1  -0.484605 -0.226629  0.834595  0.382444
# 2   1.002624 -0.352282  0.811769 -0.771234
# 3   1.279125 -0.219258  0.463970  1.710032
# 4   0.827671 -0.161500 -0.603888 -0.991564
# 5  -1.174889  0.790357  0.277971 -0.562625
# 6  -0.156444  1.317961  0.460263  0.143097
# 7   0.354895 -0.314679 -0.949182 -1.118730
# 8  -1.085285 -0.135187 -0.045841 -0.068558
# 9  -0.904385  0.281998  2.817118  0.964935
# 10  0.100230  0.498819 -1.332437  1.528207
# 11 -1.257667  0.997186  1.181825 -0.386610
# 12  1.478010  0.914310 -2.055094 -0.242988
# 13  0.376282  0.084568  0.906954 -0.330540
# 14  0.189882 -0.254156 -0.166407  1.174214
# 15  0.144269 -1.982706  1.309398 -0.298349
# 16 -1.553618  0.362949 -0.489144 -0.742669
# 17  0.009313 -0.788533  0.445267 -1.704204
# 18 -0.957463 -0.011264 -0.247352  1.399010
# 19  1.645806  0.227912 -1.246545  0.173152
# 20 -0.843259 -0.150075  0.855650 -0.676852
# ...
